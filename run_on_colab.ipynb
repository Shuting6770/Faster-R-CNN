# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/Shuting6770/Faster-R-CNN.git
# %cd Faster-R-CNN/
# Out:
# Cloning into 'Faster-R-CNN'...
# remote: Enumerating objects: 1057, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 1057 (delta 6), reused 16 (delta 4), pack-reused 1036
# Receiving objects: 100% (1057/1057), 164.90 MiB | 15.62 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# /content/Faster-R-CNN

# %%
# !cp /content/gdrive/MyDrive/nuimages/nuimages.zip ./
# !unzip ./nuimages.zip -d ./

# %%
# !rm -rf logs
# !ln -s /content/gdrive/MyDrive/Models/voc-weights-resnet/logs logs

# %%
# !python voc_annotation.py
# !python train.py
# Out:
# generate car_train.txt
# generate human_train.txt
# generate val.txt
# number of classes: 2
# Number of devices: 1
# initialize network with normal type
# Load weights /content/gdrive/MyDrive/Models/voc-weights-resnet/model_data/voc_weights_resnet.pth.
#
# Successful Load Key: ['extractor.0.weight', 'extractor.1.weight', 'extractor.1.bias', 'extractor.1.running_mean', 'extractor.1.running_var', 'extractor.1.num_batches_tracked', 'extractor.4.0.conv1.weight', 'extractor.4.0.bn1.weight', 'extractor.4.0.bn1.bias', 'extractor.4.0.bn1.running_mean', 'extractor.4.0.bn1.running_var', 'extractor.4.0.bn1.num_batches_tracked', 'extractor.4.0.conv2.weight', 'extractor.4.0.bn2.weight', 'extractor.4.0.bn2.bias', 'extractor.4.0.bn2.running_mean', 'extractor.4.0.bn2.running_var', 'e ……
# Successful Load Key Num: 324
#
# Fail To Load Key: ['head.cls_loc.weight', 'head.cls_loc.bias', 'head.score.weight', 'head.score.bias'] ……
# Fail To Load Key num: 4
#
# 温馨提示，head部分没有载入是正常现象，Backbone部分没有载入是错误的。
# ...

# %%
run predict.py
# Out:
# /content/gdrive/MyDrive/Models/voc-weights-resnet/logs/best_epoch_weights.pth model, anchors, and classes loaded.
# Configurations:
# ----------------------------------------------------------------------
# |                     keys |                                   values|
# ----------------------------------------------------------------------
# |               model_path | /content/gdrive/MyDrive/Models/voc-weights-resnet/logs/best_epoch_weights.pth|
# |             classes_path |               model_data/voc_classes.txt|
# |                 backbone |                                 resnet50|
# |               confidence |                                      0.5|
# |                  nms_iou |                                      0.3|
# |             anchors_size |                              [8, 16, 32]|
# |                     cuda |                                     True|
# ----------------------------------------------------------------------
# ...
